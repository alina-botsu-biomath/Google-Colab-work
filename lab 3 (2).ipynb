# %%
import numpy as np

# %% [markdown]
# Створіть матрицю розміром 20 × 4 із рівномірного розподілу між −5 та 5.

# %%
a = np.random.randint(-5, 5, size=(20, 4))
a
# Out:
# array([[-3, -1,  1, -2],
#        [-1,  2, -3, -3],
#        [-2,  2, -4, -4],
#        [ 2, -3,  1, -2],
#        [-1,  3,  2,  0],
#        [ 3,  0,  3,  3],
#        [-1,  4, -2,  2],
#        [ 3,  4,  2,  2],
#        [ 1,  1, -5,  0],
#        [ 2,  0, -4,  1],
#        [ 1, -5, -2, -4],
#        [-4,  2,  2, -3],
#        [-1, -2, -1,  2],
#        [-5,  0, -4,  4],
#        [-4,  4,  2,  0],
#        [ 2, -4, -2, -1],
#        [ 4,  2,  2, -5],
#        [ 1,  2,  0, -5],
#        [-2,  0, -4, -1],
#        [-3, -5,  0, -3]])

# %% [markdown]
# Виведіть перші 10 рядків матриці.

# %%
a[:10]
# Out:
# array([[-3, -1,  1, -2],
#        [-1,  2, -3, -3],
#        [-2,  2, -4, -4],
#        [ 2, -3,  1, -2],
#        [-1,  3,  2,  0],
#        [ 3,  0,  3,  3],
#        [-1,  4, -2,  2],
#        [ 3,  4,  2,  2],
#        [ 1,  1, -5,  0],
#        [ 2,  0, -4,  1]])

# %% [markdown]
# Знайдіть суму двох останніх стовпців.

# %%
sum(a)
# Out:
# array([ -8,   6, -16, -19])

# %%
sum(a)[:2]
# Out:
# array([-8,  6])

# %%
sum(a)[2:]
# Out:
# array([-16, -19])

# %% [markdown]
# Знайдіть мінімальне значення у п'ятому рядку.

# %%
np.max(a, axis=1)[4]
# Out:
# 3

# %% [markdown]
# Знайдіть середнє значення а) у першому стовпці; б) у кожному стовпці.

# %%
np.mean(a, axis=0)[0] #a
# Out:
# -0.4

# %%
np.mean(a, axis=0) #b
# Out:
# array([-0.4 ,  0.3 , -0.8 , -0.95])

# %% [markdown]
# Створіть нову матрицю того ж розміру, елементи якої обчислюються за правилом: :
# bij = aij − mini, де aij - елементи вихідної матриці, mini- мінімальний елемент в i -му рядку.

# %% [markdown]
# Знайдіть рядки, середнє значення яких є негативним.

# %%
a[np.mean(a, axis=1)<0] #b
# Out:
# array([[-3, -1,  1, -2],
#        [-1,  2, -3, -3],
#        [-2,  2, -4, -4],
#        [ 2, -3,  1, -2],
#        [ 1,  1, -5,  0],
#        [ 2,  0, -4,  1],
#        [ 1, -5, -2, -4],
#        [-4,  2,  2, -3],
#        [-1, -2, -1,  2],
#        [-5,  0, -4,  4],
#        [ 2, -4, -2, -1],
#        [ 1,  2,  0, -5],
#        [-2,  0, -4, -1],
#        [-3, -5,  0, -3]])

# %%
np.mean(a, axis=1)<0
# Out:
# array([ True, False, False,  True,  True,  True,  True,  True,  True,
#         True, False,  True, False, False, False, False,  True, False,
#        False,  True])

# %% [markdown]
# Знайдіть стовпці, різниця між максимальним та мінімальним значенням у яких
# більше 5.

# %%
a[np.max(a, axis=1)-np.min(a, axis=1)>5]
# Out:
# array([[-2,  2, -4, -4],
#        [-1,  4, -2,  2],
#        [ 1,  1, -5,  0],
#        [ 2,  0, -4,  1],
#        [ 1, -5, -2, -4],
#        [-4,  2,  2, -3],
#        [-5,  0, -4,  4],
#        [-4,  4,  2,  0],
#        [ 2, -4, -2, -1],
#        [ 4,  2,  2, -5],
#        [ 1,  2,  0, -5]])

# %%
np.max(a, axis=1)
# Out:
# array([1, 2, 2, 2, 3, 3, 4, 4, 1, 2, 1, 2, 2, 4, 4, 2, 4, 2, 0, 0])

# %%
np.min(a, axis=1)
# Out:
# array([-3, -3, -4, -3, -1,  0, -2,  2, -5, -4, -5, -4, -2, -5, -4, -4, -5,
#        -5, -4, -5])

# %%
np.max(a, axis=1)-np.min(a, axis=1)>5
# Out:
# array([False, False,  True, False, False, False,  True, False,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#        False, False])

# %% [markdown]
# Транспонуйте матрицю та видаліть з неї перші 5 стовпців.

# %%
b=a.T
b
# Out:
# array([[-3, -1, -2,  2, -1,  3, -1,  3,  1,  2,  1, -4, -1, -5, -4,  2,
#          4,  1, -2, -3],
#        [-1,  2,  2, -3,  3,  0,  4,  4,  1,  0, -5,  2, -2,  0,  4, -4,
#          2,  2,  0, -5],
#        [ 1, -3, -4,  1,  2,  3, -2,  2, -5, -4, -2,  2, -1, -4,  2, -2,
#          2,  0, -4,  0],
#        [-2, -3, -4, -2,  0,  3,  2,  2,  0,  1, -4, -3,  2,  4,  0, -1,
#         -5, -5, -1, -3]])

# %%
delete = [15,16,17,18,19]
m = np.delete(b, delete, axis=1)
m
# Out:
# array([[-3, -1, -2,  2, -1,  3, -1,  3,  1,  2,  1, -4, -1, -5, -4],
#        [-1,  2,  2, -3,  3,  0,  4,  4,  1,  0, -5,  2, -2,  0,  4],
#        [ 1, -3, -4,  1,  2,  3, -2,  2, -5, -4, -2,  2, -1, -4,  2],
#        [-2, -3, -4, -2,  0,  3,  2,  2,  0,  1, -4, -3,  2,  4,  0]])

# %% [markdown]
# Додайте до матриці стовпець одиниць (праворуч).

# %%
one = np.array([[1],[1],[1],[1]])
print(one)
# Out:
# [[1]
#  [1]
#  [1]
#  [1]]

# %%
onem=np.hstack([m, one])
onem
# Out:
# array([[-3, -1, -2,  2, -1,  3, -1,  3,  1,  2,  1, -4, -1, -5, -4,  1],
#        [-1,  2,  2, -3,  3,  0,  4,  4,  1,  0, -5,  2, -2,  0,  4,  1],
#        [ 1, -3, -4,  1,  2,  3, -2,  2, -5, -4, -2,  2, -1, -4,  2,  1],
#        [-2, -3, -4, -2,  0,  3,  2,  2,  0,  1, -4, -3,  2,  4,  0,  1]])

# %% [markdown]
# Додайте до матриці п'ять нульових рядків (згори).

# %%
null = np.array([[-3 for j in range(15)] for i in range(4)])
null
# Out:
# array([[-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3],
#        [-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3],
#        [-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3],
#        [-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3]])

# %%
 mnull=np.concatenate([null,m])
 mnull
# Out:
# array([[-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3],
#        [-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3],
#        [-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3],
#        [-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3],
#        [-3, -1, -2,  2, -1,  3, -1,  3,  1,  2,  1, -4, -1, -5, -4],
#        [-1,  2,  2, -3,  3,  0,  4,  4,  1,  0, -5,  2, -2,  0,  4],
#        [ 1, -3, -4,  1,  2,  3, -2,  2, -5, -4, -2,  2, -1, -4,  2],
#        [-2, -3, -4, -2,  0,  3,  2,  2,  0,  1, -4, -3,  2,  4,  0]])

# %% [markdown]
# Видаліть рядки, всі елементи яких є негативними.

# %%
(mnull >= 0).all(axis=1)
# Out:
# array([ True,  True,  True,  True, False, False, False, False])

# %%
mnull[(mnull <= 0).all(axis=1)]
# Out:
# array([[-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3],
#        [-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3],
#        [-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3],
#        [-3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3, -3]])

# %%
mnull[(mnull >= 0).all(axis=1)]
# Out:
# array([], shape=(0, 15), dtype=int64)
