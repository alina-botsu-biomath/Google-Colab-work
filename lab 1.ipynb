# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Завантажте за посиланням набір даних про об’єктах нерухомості, проданих в
# окрузі King County (Вашингтон, США) в період з травня 2014 по травень 2015 року.
# Детальніше про цих даних можна, можливо прочитати тут.

# %% [markdown]
# Збережіть дані у вигляді датафрейму Pandas (попередньо необхідно завантажити
# дані у форматі CSV, TSV або Excel).

# %%
path = "/content/drive/MyDrive/kc_house_data - kc_house_data.csv"
data = pd.read_csv(path, sep=',')
data.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#        lat     long  sqft_living15  sqft_lot15
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
# ...

# %% [markdown]
# Зобразіть розподіл цін на будинку (стовпець price) у вигляді гістограми. Підберіть
# кількість інтервалів (bins) експериментально. Додати підпис до осі Ox та назва
# графіка.

# %%
data.value_counts("price")#.plot(kind='hist')
# Out:
# price
# 350000.0     172
# 450000.0     172
# 550000.0     159
# 500000.0     152
# 425000.0     150
#             ...
# 427550.0       1
# 427800.0       1
# 427874.0       1
# 428040.0       1
# 7700000.0      1
# Name: count, Length: 3625, dtype: int64

# %%
data["price"].plot(kind='hist',bins=30)
plt.ylabel('Count')
plt.title('Prise for bildings')
plt.xlabel('prise')
plt.show()

# %% [markdown]
# Побудуйте графік для візуалізації співвідношення загальної житловий площі (sqft_living)
# та ціни (price). Задайте параметри графіка:
#
# • підписи до осей, назва графіка ;
#
# • тип маркера: circle; розмір: 20; колір: зелений.

# %%
style=dict(markers="circle", size=20, color="green")
sns.scatterplot(y="sqft_living", x="price", data=data,**style, legend=False)
plt.title('Візуалізація співвідношення загальної житлової площі та ціни')
plt.xlabel('Ціна')
plt.ylabel('Загальна житлова площа')
plt.show()

# %% [markdown]
# Доповніть параметри попереднього графіка, щоб показати наявність / відсутність
# виду на море (стовпець waterfront).
# Зробіть розбиття на групи по ознакою waterfront шляхом поділу на два графіка. Яка
# з двох останніх візуалізацій наочніше доносить інформацію?

# %%
sns.countplot(x="waterfront",data=data)
# Out:
# <Axes: xlabel='waterfront', ylabel='count'>

# %%
data["waterfront"].value_counts()
# Out:
# waterfront
# 0    21450
# 1      163
# Name: count, dtype: int64

# %%
#style=dict(markers="circle", size=20, color="green")
sns.scatterplot(y="sqft_living", x="price", data=data, hue="waterfront")# hue_order=[1=="Yes",0== "No"])#**style, legend=False)
plt.title('Візуалізація співвідношення загальної житлової площі та ціни')
plt.xlabel('Ціна')
plt.ylabel('Загальна житлова площа')
plt.show()

# %%
#style=dict(markers="circle", size=20, color="green")
sns.scatterplot(y="sqft_living", x="price", data=data, hue="waterfront", hue_order=["Yes", "No"])#**style, legend=False)
plt.title('Візуалізація співвідношення загальної житлової площі та ціни')
plt.xlabel('Ціна')
plt.ylabel('Загальна житлова площа')
plt.show()

# %%
#palette_colors = {0: "green", 1: "blue"}
sns.relplot(x="price",
            y="sqft_living",
            data=data,
            kind="scatter",
            col="waterfront"
          )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-1641139436.py in <cell line: 0>()
#       1 #palette_colors = {0: "green", 1: "blue"}
# ----> 2 sns.relplot(x="price",
#       3             y="sqft_living",
#       4             data=data,
#       5             kind="scatter",
#
# NameError: name 'sns' is not defined

# %% [markdown]
# Яка з двох останніх візуалізацій наочніше доносить інформацію?
#
# Найкраще доносить інформацію про кількість квартир з видом на море 2 візуралізацію, тому же вона чітко показуе які квартири з видом на море, а які без нього.

# %% [markdown]
# Зобразіть розподіл року будівлі дому (yr _built). Задайте параметри графіка.

# %%
sns.histplot(x="yr_built", data=data)
plt.title('Розподіл року будівлі дому')
plt.show()

# %% [markdown]
# Зобразіть розподіл кількості будинків по загальної оцінки (grade).

# %%
sns.displot(x="grade", data=data)
plt.title('Розподіл року будівлі дому')
plt.show()

# %% [markdown]
# Зобразіть співвідношення між загальної оцінкою дому (grade) та середньої ціною
# будинків з даною оцінкою (перед цим необхідно зробити відповідні обчислення).

# %%
grade_price=data.groupby("grade")[["price"]].mean()
grade_price
# Out:
#               price
# grade
# 1      1.420000e+05
# 3      2.056667e+05
# 4      2.143810e+05
# 5      2.485240e+05
# 6      3.019166e+05
# 7      4.025933e+05
# 8      5.428955e+05
# 9      7.737382e+05
# 10     1.072347e+06
# 11     1.497792e+06
# 12     2.192500e+06
# 13     3.710769e+06

# %%
sns.relplot(x="price",
            y="grade",
            data=grade_price,
            kind="line",
          )
plt.title('співвідношення між загальної оцінкою дому та середньої ціною будинків з даною оцінкою')
plt.xlabel('Ціна')
plt.ylabel('Oцінкa')
plt.show()

# %% [markdown]
# Зобразіть на двох сусідніх графіки (за загальною віссю Oy) розподіл будинків по
# кількості спалень (bedrooms) та ванних кімнат кімнат (bathrooms).

# %%
data["bedrooms"].value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
data["bathrooms"]#()
# Out:
# 0        1.00
# 1        2.25
# 2        1.00
# 3        3.00
# 4        2.00
#          ...
# 21608    2.50
# 21609    2.50
# 21610    0.75
# 21611    2.50
# 21612    0.75
# Name: bathrooms, Length: 21613, dtype: float64

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 7), sharey=True)

sns.histplot(data['bedrooms'], bins=range(0, 11), kde=False, ax=ax1)
ax1.set_title('Distribution of Bedrooms')
ax1.set_xlabel('Number of Bedrooms')
ax1.set_ylabel('Count')

# Bathrooms distribution
sns.histplot(data['bathrooms'], bins=np.arange(0, 8, 1), kde=False, ax=ax2)
ax2.set_title('Distribution of Bathrooms')
ax2.set_xlabel('Number of Bathrooms')
# Out:
# Text(0.5, 0, 'Number of Bathrooms')

# %% [markdown]
# Залежить чи ціна будинку від його географічного розташування (широти lat і довготи long)? Подумайте над належним типом візуалізації.

# %%
sns.relplot(x="long", y="lat", hue="price",
            data=data, kind="scatter")

# %%
# @title Текст заголовка по умолчанию
sns.countplot(y=region)
palette_colors = {"Rural": "green", "Urban": "blue"}
grade_pr=data[["grade","price"]]
grade_pr
price_grade=grade_pr.groupby("grade")["price"].mean()
price_grade

# Make the shaded area show the standard deviation
sns.relplot(x="model_year", y="mpg",
            data=mpg, kind="line",
            ci="sd")


# Show plot
plt.show()

# Separate into column subplots based on age category
sns.catplot(y="Internet usage", data=survey_data,
            kind="count", col="Age Category")

# Show plot
plt.show()

# Create a bar plot of interest in math, separated by gender
sns.catplot(x="Gender", y="Interested in Math",
            data=survey_data, kind="bar")

# Show plot
plt.show()

# List of categories from lowest to highest
category_order = ["<2 hours",
                  "2 to 5 hours",
                  "5 to 10 hours",
                  ">10 hours"]

# Turn off the confidence intervals
sns.catplot(x="study_time", y="G3",
            data=student_data,
            kind="bar",
            order=category_order,
            ci=None)

# Show plot
plt.show()
